# %% [markdown]
# # 02 - Feature Engineering
#
# Engineer features: Rint, motion features, and other derived features.

# %%
# Import libraries
import pandas as pd
import numpy as np
from src.features import calculate_rint, extract_motion_features, engineer_features

# %%
# Load processed data
# TODO: Load cleaned data from data/processed/

# %%
# Engineer features
# TODO: Calculate Rint, motion features, etc.
