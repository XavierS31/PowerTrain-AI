# %% [markdown]
# # 04 - Model Evaluation
#
# Evaluate model performance with metrics and visualizations.

# %%
# Import libraries
import torch
import matplotlib.pyplot as plt
import seaborn as sns
from src.evaluate import calculate_metrics, plot_predictions, plot_training_history

# %%
# Load trained model
# TODO: Load model from models/saved/

# %%
# Evaluate on test set
# TODO: Make predictions and calculate metrics

# %%
# Generate plots
# TODO: Create evaluation plots and save to models/results/
